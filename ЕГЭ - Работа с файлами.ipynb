# %% [markdown]
# ### **Работа "в классе"**

# %% [markdown]
# **Тип 10 № 76113**

# %%
f = open("local/Гончаров.txt", 'r', encoding='utf-8')
l = f.read()
zp = '.,!?«»:;()"[]{}…'
for i in zp:
   l=l.replace(i, '')
l =l.replace('\n', ' ')
l =l.replace('-', ' ')
l = l.split()

c = 0
for i in l:
    a = i.lower()
    lena = len(i)
    if (a[0] == 'м' or a[0] == 'm') and (a[-1] == 'а' or a[-1] == 'a') and (lena>= 4):
        c +=1
        # print(a)
print(c)

f.close()
# Out:
# 64

# %% [markdown]
# Тип 17 №
# 75281

# %%
f=open('GitHub/ConstAnTeenOpel/local/17.txt', encoding = 'utf-8')
h = f.read()

contra = 0
h = h.split('\n') 
h =[int(i) for i in h if len(i)>0]
maxim = max(h)
minim = min(h)
summ = 0
for i in range(len(h)-2):
    a = h[i]
    b = h[i+1]
    c = h[i+2]
    if (10>a/1000>=1) or (10>b/1000>=1) or (10>c/1000>=1):
        if ((a%5 == maxim%5) +(b%5 == maxim%5) +(c%5 == maxim%5))<=1:
            if  ((a%7 == minim%7) +(b%7 == minim%7) +(c%7 == minim%7))>=2:
                contra += 1
                if (a+b+c)>summ:
                    summ = a+b+c

#print(h)
print(contra, summ)
f.close()
# Out:
# 120 194137

# %% [markdown]
# ### **Домашнее задание**

# %% [markdown]
# Тип 17 №
# 37360

# %%
ramstor = open('local/171.txt', encoding = 'utf-8')
stor = ramstor.read()
c1 = 0
cmax = 0
stor = stor.split('\n')
stor = [int(i) for i in stor if len(i)>0]
for i in range(len(stor)-1):
    summm = stor[i]+stor[i+1]
    if (summm % 120) ==0:
        c1 +=1
        if summm > cmax:
            cmax = summm
print(c1,cmax)
ramstor.close()
# Out:
# 81 17400

# %% [markdown]
# Тип 17 №
# 57424

# %%
f = open('local/1_17.txt', encoding = 'utf-8')
h = f.read()

c1= 0
c2= 0
h = h.split('\n') 
h =[int(i) for i in h if len(i)>0]
maxix= 0
for i in h:
    if (i>maxix) and (100>i>=10):
        maxix = i
for i in range(len(h)-1):
    a = h[i]
    b = h[i+1]
    if ((10>a/10>=1) ^ (10>b/10>=1)) and ((a+b)%maxix ==0):
        c1 +=1
        c2 = max(c2,a+b)
print(c1,c2)
f.close()
# Out:
# 16 9702

# %% [markdown]
# ### **Работа "в классе"**

# %% [markdown]
# **Тип 24 № 59702**

# %%
import time
t0 = time.time()

f = open('local/24_1.txt', encoding = 'utf-8')

s = f.read()[:-1]
s = s.split("Y")
h = [len(i) for i in s]
k = [sum(h[i:i+151]) for i in range(len(h) - 151)]
print(max(k) + 150)

f.close()


print(f"{time.time() - t0} секунд")
# Out:
# 244
# 13.227495908737183 секунд

# %%
import time
t0 = time.time()

f = open('local/24_1.txt', encoding = 'utf-8')

c = 0
s = f.read()[:-1]

for i in range(len(s)):
    hui = i
    yc = 0
    while yc<=150:
        if s[hui] == 'Y':    
            yc+=1
        hui+=1
        if yc== 150:
            c= max(c, hui-i)
print(c)
f.close()

print(f"{time.time() - t0} секунд")

# %%
f = open('local/24_1.txt', encoding = 'utf-8')

c = 0
y = ""
yc = 0
s = f.read()[:-1]
for i in s:
    y = y + i
    if i == "Y":
        yc += 1
    if yc <= 150:
        c = max(c, len(y))
    else:
        yc -= 1
        j = y.find("Y")
        y = y[j:]
        
print(c)

f.close()

# %% [markdown]
# **Тип 24 № 47228**

# %%
f = open('local/24_2.txt', encoding = 'utf-8')

s = f.read()
c = 0
c1 = 0
i = 0
while i < len(s):
    if (s[i] in "CDF") and (s[i+1] in 'AO'):
        c1 +=1
        i += 1
    else:
        c = max(c,c1)
        c1 = 0
    i += 1
    
print(c)
f.close()
# Out:
# 95

# %% [markdown]
# ### **Домашнее задание**

# %% [markdown]
# **Тип 24 № 27694**

# %% [markdown]
# **Тип 24 № 83182**
